# %% [markdown]
# ## Data Collection

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
#loading the zomato dataset and assigning to variable 'df'
df = pd.read_csv('zomato.csv',sep=',', encoding='latin-1')

# %%
df.shape
# Out:
# (9551, 21)

# %%
code = pd.read_excel('Country-Code.xlsx', sheet_name='Sheet1')

# %%
code
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
dfm = df.merge(code, on='Country Code', how='inner')

# %%
dfm.head() #Calling the head method on merged datasets dfm to print the first several rows of the data
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
#  21  Country               9551 non-null   object
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB

# %%
dfm.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
dfm.shape
# Out:
# (9551, 22)

# %%
ind_res = dfm[dfm['Country'] == 'India'] #Zomato Restaurants in India 
ind_res
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# 624    Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 625    Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 626    Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra
# 627    Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...
# 628    Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...
# ...     ...                                                ...
# 9271  Vizag  Beach Road, Near Bus Stop, Sagar Nagar, Visakh...
# 9272  Vizag  Plot 95, Opposite St. Lukes Nursing School, Da...
# 9273  Vizag         Plot 17, Gangapur Layout, Siripuram, Vizag
# 9274  Vizag  The Park, Beach Road, Pedda Waltair, Lawsons B...
# 9275  Vizag  10-50-12/F2, Sai Dakshata Complex, Beside Leno...
#
#                    Locality              Locality Verbose  Longitude  \
# 624              Agra Cantt              Agra Cantt, Agra  78.011544
# 625              Agra Cantt              Agra Cantt, Agra   0.000000
# 626              Agra Cantt              Agra Cantt, Agra  78.011608
# 627             Civil Lines             Civil Lines, Agra  77.998092
# 628             Civil Lines             Civil Lines, Agra  78.007553
# ...                     ...                           ...        ...
# 9271            Sagar Nagar            Sagar Nagar, Vizag  83.361377
# 9272              Siripuram              Siripuram, Vizag   0.000000
# 9273              Siripuram              Siripuram, Vizag  83.315281
# 9274  The Park, Lawsons Bay  The Park, Lawsons Bay, Vizag  83.336840
# 9275        Waltair Uplands        Waltair Uplands, Vizag  83.314942
#
#        Latitude                                           Cuisines  ...  \
# 624   27.161661                              North Indian, Mughlai  ...
# 625    0.000000                              North Indian, Mughlai  ...
# 626   27.160832                                       North Indian  ...
# 627   27.195928                                         Rajasthani  ...
# 628   27.201725                     North Indian, Chinese, Mughlai  ...
# ...         ...                                                ...  ...
# 9271  17.764287  Continental, Seafood, Chinese, North Indian, B...  ...
# 9272   0.000000                        Cafe, North Indian, Chinese  ...
# 9273  17.719539                             Burger, Pizza, Biryani  ...
# 9274  17.721182          American, North Indian, Thai, Continental  ...
# 9275  17.721119                                            Italian  ...
#
#       Has Table booking Has Online delivery Is delivering now  \
# 624                  No                  No                No
# 625                  No                  No                No
# 626                  No                  No                No
# 627                  No                  No                No
# 628                  No                  No                No
# ...                 ...                 ...               ...
# 9271                 No                  No                No
# 9272                 No                  No                No
# 9273                 No                  No                No
# 9274                 No                  No                No
# 9275                 No                  No                No
#
#      Switch to order menu Price range Aggregate rating  Rating color  \
# 624                    No           3              3.9        Yellow
# 625                    No           2              3.5        Yellow
# 626                    No           2              3.6        Yellow
# 627                    No           2              4.0         Green
# 628                    No           3              4.2         Green
# ...                   ...         ...              ...           ...
# 9271                   No           2              3.6        Yellow
# 9272                   No           2              3.7        Yellow
# 9273                   No           2              4.3         Green
# 9274                   No           4              3.8        Yellow
# 9275                   No           3              4.4         Green
#
#       Rating text Votes Country
# 624          Good   140   India
# 625          Good    71   India
# 626          Good    94   India
# 627     Very Good    87   India
# 628     Very Good   177   India
# ...           ...   ...     ...
# 9271         Good   193   India
# 9272         Good    85   India
# 9273    Very Good   172   India
# 9274         Good    74   India
# 9275    Very Good   316   India
#
# [8652 rows x 22 columns]

# %%
ind_res.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ind_res.shape
# Out:
# (8652, 22)

# %%
ind_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8652 entries, 624 to 9275
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         8652 non-null   int64
#  1   Restaurant Name       8652 non-null   object
#  2   Country Code          8652 non-null   int64
#  3   City                  8652 non-null   object
#  4   Address               8652 non-null   object
#  5   Locality              8652 non-null   object
#  6   Locality Verbose      8652 non-null   object
#  7   Longitude             8652 non-null   float64
#  8   Latitude              8652 non-null   float64
#  9   Cuisines              8652 non-null   object
#  10  Average Cost for two  8652 non-null   int64
#  11  Currency              8652 non-null   object
#  12  Has Table booking     8652 non-null   object
#  13  Has Online delivery   8652 non-null   object
#  14  Is delivering now     8652 non-null   object
#  15  Switch to order menu  8652 non-null   object
#  16  Price range           8652 non-null   int64
#  17  Aggregate rating      8652 non-null   float64
#  18  Rating color          8652 non-null   object
#  19  Rating text           8652 non-null   object
#  20  Votes                 8652 non-null   int64
#  21  Country               8652 non-null   object
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.5+ MB

# %%
ind_res.isnull().mean()*100 #Checking for null values
# Out:
# Restaurant ID           0.0
# Restaurant Name         0.0
# Country Code            0.0
# City                    0.0
# Address                 0.0
# Locality                0.0
# Locality Verbose        0.0
# Longitude               0.0
# Latitude                0.0
# Cuisines                0.0
# Average Cost for two    0.0
# Currency                0.0
# Has Table booking       0.0
# Has Online delivery     0.0
# Is delivering now       0.0
# Switch to order menu    0.0
# Price range             0.0
# Aggregate rating        0.0
# Rating color            0.0
# Rating text             0.0
# Votes                   0.0
# Country                 0.0
# dtype: float64

# %%
ind_res.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   8.652000e+03        8652.0  8652.000000  8652.000000
# mean    8.657085e+06           1.0    72.856786    26.420652
# std     8.959437e+06           0.0    18.017536     6.976576
# min     5.300000e+01           1.0     0.000000     0.000000
# 25%     3.007402e+05           1.0    77.098797    28.491425
# 50%     2.200006e+06           1.0    77.203468    28.569869
# 75%     1.836120e+07           1.0    77.285356    28.637857
# max     1.850065e+07           1.0    91.806493    35.000000
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           8652.000000  8652.000000       8652.000000   8652.000000
# mean             623.370319     1.721683          2.523324    137.212552
# std              595.676124     0.852544          1.510986    428.039513
# min                0.000000     1.000000          0.000000      0.000000
# 25%              300.000000     1.000000          2.100000      4.000000
# 50%              450.000000     2.000000          3.100000     24.000000
# 75%              700.000000     2.000000          3.600000    100.000000
# max             8000.000000     4.000000          4.900000  10934.000000

# %%
vizag_res = ind_res[ind_res.City == 'Vizag']
vizag_res.shape
# Out:
# (20, 22)

# %%
vizag_res.head()
# Out:
#       Restaurant ID             Restaurant Name  Country Code   City  \
# 9256        2800013                   Pizza Hut             1  Vizag
# 9257        2800012                   Pizza Hut             1  Vizag
# 9258        2800294          Sri Sairam Parlour             1  Vizag
# 9259        2800903    Mekong - Hotel GreenPark             1  Vizag
# 9260        2800052  The Square - Hotel Novotel             1  Vizag
#
#                                                 Address  \
# 9256  52-1-35,36&38, CMR Mall, New Resapavanipalem, ...
# 9257  Plot No 47- 10-23/3, 5th Floor, Isnar Khazana ...
# 9258  Diamond Park, Railway New Colony Road, Dwaraka...
# 9259  Hotel GreenPark, Waltair Main Road, Waltair Up...
# 9260    Hotel Novotel, Beach Road, Maharani Peta, Vizag
#
#                             Locality                       Locality Verbose  \
# 9256  CMR Central Mall, Maddilapalem  CMR Central Mall, Maddilapalem, Vizag
# 9257                   Dwaraka Nagar                   Dwaraka Nagar, Vizag
# 9258                   Dwaraka Nagar                   Dwaraka Nagar, Vizag
# 9259          Hotel GreenPark, Vizag          Hotel GreenPark, Vizag, Vizag
# 9260    Hotel Novotel, Maharani Peta    Hotel Novotel, Maharani Peta, Vizag
#
#       Longitude   Latitude                                           Cuisines  \
# 9256  83.318511  17.734178                                   Pizza, Fast Food
# 9257  83.305139  17.726147                                   Pizza, Fast Food
# 9258  83.303414  17.726297                         South Indian, North Indian
# 9259  83.307073  17.715819  Chinese, Thai, Burmese, Vietnamese, Tibetan, J...
# 9260  83.315935  17.710690                          Continental, North Indian
#
#       ...  Has Table booking Has Online delivery Is delivering now  \
# 9256  ...                 No                  No                No
# 9257  ...                 No                  No                No
# 9258  ...                 No                  No                No
# 9259  ...                 No                  No                No
# 9260  ...                 No                  No                No
#
#      Switch to order menu Price range Aggregate rating  Rating color  \
# 9256                   No           2              4.6    Dark Green
# 9257                   No           2              4.3         Green
# 9258                   No           1              4.2         Green
# 9259                   No           3              4.4         Green
# 9260                   No           4              4.1         Green
#
#       Rating text Votes Country
# 9256    Excellent   289   India
# 9257    Very Good   230   India
# 9258    Very Good   270   India
# 9259    Very Good    73   India
# 9260    Very Good   125   India
#
# [5 rows x 22 columns]

# %%
plt.scatter(vizag_res['Votes'],vizag_res['Price range'], marker = '.')
